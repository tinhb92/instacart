# %%
import feather
import os

# %%
INPUT = '/media/tin/DATA/Kaggle/Instacart/Input/'
orders = feather.read_dataframe(os.path.join(INPUT, 'orders.feather'))

orders = orders[:10000]

# %%
orders.shape
# Out:
# (10000, 7)

# %% [raw]
# Munging

# %%
orders.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
orders.groupby(['user_id', 'order_hour_of_day']).size()
# Out:
# user_id  order_hour_of_day
# 1        7                     3
#          8                     3
#          9                     1
#          12                    1
#          14                    1
#          15                    1
#          16                    1
# 2        9                     3
#          10                    5
#          11                    5
#          12                    1
#          15                    1
# 3        14                    1
#          15                    3
#          16                    4
#          17                    2
#          18                    2
#          19                    1
# 4        11                    2
#          12                    1
#          13                    2
#          15                    1
# 5        11                    1
#          12                    1
#          16                    1
#          18                    2
# 6        16                    2
# ...

# %%
orders.groupby('user_id').mean().add_prefix('88')
# Out:
#            88order_id  88order_number  88order_dow  88order_hour_of_day  \
# user_id
# 1        1.923450e+06             6.0     2.636364            10.090909
# 2        1.768105e+06             8.0     2.066667            10.600000
# 3        1.934104e+06             7.0     1.384615            16.307692
# 4        1.507835e+06             3.5     4.500000            12.500000
# 5        1.849579e+06             3.0     1.400000            15.000000
# 6        1.227932e+06             2.5     3.500000            17.000000
# 7        1.782059e+06            11.0     1.857143            13.476190
# 8        1.757722e+06             2.5     3.250000             5.500000
# 9        1.491937e+06             2.5     3.000000            13.250000
# 10       1.111320e+06             3.5     3.000000            17.000000
# 11       1.824031e+06             4.5     4.500000            10.875000
# 12       1.213758e+06             3.5     2.666667            11.166667
# ...
